# %%
import pandas as pd
from yahoofinancials import YahooFinancials
import quandl
import numpy as np

# %%
quandl.ApiConfig.api_key = 'sPcyJCa9JnEWzz6JiWMz'

# %%
data = quandl.get("EIA/PET_RWTC_D")
print(data)
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2020-05-05  24.56
# 2020-05-06  23.88
# 2020-05-07  23.68
# 2020-05-08  24.73
# 2020-05-11  24.02
#
# [8679 rows x 1 columns]

# %%
dataNum = quandl.get("EIA/PET_RWTC_D", returns="numpy")
print(dataNum)
# Out:
# [('1986-01-02T00:00:00.000000000', 25.56)
#  ('1986-01-03T00:00:00.000000000', 26.  )
#  ('1986-01-06T00:00:00.000000000', 26.53) ...
#  ('2020-05-07T00:00:00.000000000', 23.68)
#  ('2020-05-08T00:00:00.000000000', 24.73)
#  ('2020-05-11T00:00:00.000000000', 24.02)]

# %%
dataApl = quandl.get("WIKI/AAPL", start_date='2017-12-01', end_date='2017-12-31')
print(dataApl)
# Out:
#               Open      High      Low    Close      Volume  Ex-Dividend  \
# Date
# 2017-12-01  169.95  171.6700  168.500  171.050  39590080.0          0.0
# 2017-12-04  172.48  172.6200  169.630  169.800  32115052.0          0.0
# 2017-12-05  169.06  171.5200  168.400  169.640  27008428.0          0.0
# 2017-12-06  167.50  170.2047  166.460  169.010  28224357.0          0.0
# 2017-12-07  169.03  170.4400  168.910  169.452  24469613.0          0.0
# 2017-12-08  170.49  171.0000  168.820  169.370  23096872.0          0.0
# 2017-12-11  169.20  172.8900  168.790  172.670  33092051.0          0.0
# 2017-12-12  172.15  172.3900  171.461  171.700  18945457.0          0.0
# 2017-12-13  172.50  173.5400  172.000  172.270  23142242.0          0.0
# 2017-12-14  172.40  173.1300  171.650  172.220  20219307.0          0.0
# 2017-12-15  173.63  174.1700  172.460  173.870  37054632.0          0.0
# 2017-12-18  174.88  177.2000  174.860  176.420  28831533.0          0.0
# ...
