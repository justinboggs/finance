# %%
import pandas as pd

# %%
uo = pd.read_csv('../data/uo.csv')
uo.head()
# Out:
#   Symbol   Price  Type  Strike  Exp Date    DTE    Bid  Midpoint    Ask  \
# 0   WKHS   28.50  Call    32.0  02/05/21   10.0   2.03      2.12   2.20
# 1   FSLR  104.14  Call   120.0  09/17/21  234.0  11.00     11.43  11.85
# 2   INSG   20.68   Put    15.0  09/17/21  234.0   2.55      2.65   2.75
# 3    TJX   65.14  Call    72.5  03/19/21   52.0   1.10      1.16   1.21
# 4   BBBY   31.93   Put    28.0  02/05/21   10.0   2.01      2.18   2.34
#
#     Last  Volume  Open Int  Vol/OI       IV Last Trade
# 0   2.44  4415.0     112.0   39.42  214.52%   10:11 ET
# 1  11.45  2019.0     117.0   17.26   50.59%   10:12 ET
# 2   2.61  5673.0     380.0   14.93   90.63%   10:02 ET
# 3   1.15  3809.0     262.0   14.54   35.96%   10:06 ET
# 4   2.11  5211.0     681.0    7.65  162.93%   10:04 ET

# %%
uoC = uo[uo['Type'] == 'Call']
uoC.head()
# Out:
#   Symbol   Price  Type  Strike  Exp Date    DTE    Bid  Midpoint    Ask  \
# 0   WKHS   28.50  Call    32.0  02/05/21   10.0   2.03      2.12   2.20
# 1   FSLR  104.14  Call   120.0  09/17/21  234.0  11.00     11.43  11.85
# 3    TJX   65.14  Call    72.5  03/19/21   52.0   1.10      1.16   1.21
# 6   OSTK   80.22  Call    90.0  01/29/21    3.0   2.83      3.07   3.30
# 7   PRTS   17.10  Call    20.0  02/19/21   24.0   1.85      1.90   1.95
#
#     Last  Volume  Open Int  Vol/OI       IV Last Trade
# 0   2.44  4415.0     112.0   39.42  214.52%   10:11 ET
# 1  11.45  2019.0     117.0   17.26   50.59%   10:12 ET
# 3   1.15  3809.0     262.0   14.54   35.96%   10:06 ET
# 6   3.00  1296.0     183.0    7.08  243.81%   10:12 ET
# 7   2.07  1465.0     212.0    6.91  181.17%   10:14 ET

# %%
uoP = uo[uo['Type'] == 'Put']
uoP.head()
# Out:
#    Symbol  Price Type  Strike  Exp Date    DTE   Bid  Midpoint   Ask  Last  \
# 2    INSG  20.68  Put    15.0  09/17/21  234.0  2.55      2.65  2.75  2.61
# 4    BBBY  31.93  Put    28.0  02/05/21   10.0  2.01      2.18  2.34  2.11
# 5    NCNO  76.17  Put    60.0  08/20/21  206.0  5.90      6.20  6.50  6.00
# 15   PLTR  36.26  Put    32.0  02/19/21   24.0  3.00      3.08  3.15  3.14
# 16    OPK   5.03  Put     5.0  01/29/21    3.0  0.19      0.20  0.21  0.20
#
#     Volume  Open Int  Vol/OI       IV Last Trade
# 2   5673.0     380.0   14.93   90.63%   10:02 ET
# 4   5211.0     681.0    7.65  162.93%   10:04 ET
# 5   1666.0     232.0    7.18   62.85%   10:08 ET
# 15  4040.0     864.0    4.68  134.67%   10:12 ET
# 16   583.0     125.0    4.66  121.10%   10:10 ET

# %%
uoC.Symbol.value_counts().head()
# Out:
# TLRY    5
# NKLA    5
# NOK     4
# CCL     3
# BYND    3
# Name: Symbol, dtype: int64

# %%
uoP.Symbol.value_counts().head()
# Out:
# NOK     3
# BGS     2
# MRNA    2
# SPWR    2
# JMIA    1
# Name: Symbol, dtype: int64
